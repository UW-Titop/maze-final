# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
import matplotlib as mpl
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from scipy import stats
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from sklearn.kernel_ridge import KernelRidge
import glob
import pandas as pd
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#reading dataset
df = pd.DataFrame(pd.read_csv("../input/finalcsv/combined_csv (8).csv"))
len(df)

# %%
df.head()

# %%
df.info()

# %%
#creating time and memory computation for creating maze for size 8
maze8 = df.loc[df['env_height'] ==  8]
maze8solve = maze8[["env_width","solver_algorithm","solver_epoch","solver_time","solver_used_memory","solver_steps"]]
maze8gen = maze8[["env_algorithm","env_generation_time","env_height","env_used_memory"]]

maze8gen = maze8gen.drop_duplicates()
time8 = maze8gen.groupby("env_algorithm")["env_generation_time"].mean()
mem8 = maze8gen.groupby("env_algorithm")["env_used_memory"].mean()
#creating time, memory, and solver steps computation for path finding for size 8
maze8solve = maze8solve.drop_duplicates()
steps8Solve = maze8solve.groupby("solver_algorithm")["solver_steps"].mean()
time8Solve = maze8solve.groupby("solver_algorithm")["solver_time"].mean()
mem8Solve = maze8solve.groupby("solver_algorithm")["solver_used_memory"].mean()

# %%
#creating time and memory computation for creating maze for size 16
maze16 = df.loc[df['env_height'] ==  16]
maze16solve = maze16[["env_width","solver_algorithm","solver_epoch","solver_time","solver_used_memory","solver_steps"]]
maze16gen = maze16[["env_algorithm","env_generation_time","env_height","env_used_memory"]]

maze16gen = maze16gen.drop_duplicates()
time16 = maze16gen.groupby("env_algorithm")["env_generation_time"].mean()
mem16 = maze16gen.groupby("env_algorithm")["env_used_memory"].mean()
#creating time, memory, and solver steps computation for path finding for size 16
maze16solve = maze16solve.drop_duplicates()
steps16Solve = maze16solve.groupby("solver_algorithm")["solver_steps"].mean()
time16Solve = maze16solve.groupby("solver_algorithm")["solver_time"].mean()
mem16Solve = maze16solve.groupby("solver_algorithm")["solver_used_memory"].mean()
maze16["env_algorithm"].unique()

# %%
#creating time and memory computation for creating maze for size 32
maze32 = df.loc[df['env_height'] ==  32]
maze32solve = maze32[["env_width","solver_algorithm","solver_epoch","solver_time","solver_used_memory","solver_steps"]]
maze32gen = maze32[["env_algorithm","env_generation_time","env_height","env_used_memory"]]

maze32gen = maze32gen.drop_duplicates()
time32 = maze32gen.groupby("env_algorithm")["env_generation_time"].mean()
mem32 = maze32gen.groupby("env_algorithm")["env_used_memory"].mean()
#creating time and memory computation for creating maze for size 32
maze32solve = maze32solve.drop_duplicates()
steps32Solve = maze32solve.groupby("solver_algorithm")["solver_steps"].mean()
time32Solve = maze32solve.groupby("solver_algorithm")["solver_time"].mean()
mem32Solve = maze32solve.groupby("solver_algorithm")["solver_used_memory"].mean()

# %%
#creating time and memory computation for creating maze for size 64
maze64 = df.loc[df['env_height'] ==  64]
maze64solve = maze64[["env_width","solver_algorithm","solver_epoch","solver_time","solver_used_memory","solver_steps"]]
maze64gen = maze64[["env_algorithm","env_generation_time","env_height","env_used_memory"]]

maze64gen = maze64gen.drop_duplicates()
time64 = maze64gen.groupby("env_algorithm")["env_generation_time"].mean()
mem64 = maze64gen.groupby("env_algorithm")["env_used_memory"].mean()
#creating time and memory computation for creating maze for size 64
maze64solve = maze64solve.drop_duplicates()
steps64Solve = maze64solve.groupby("solver_algorithm")["solver_steps"].mean()
time64Solve = maze64solve.groupby("solver_algorithm")["solver_time"].mean()
mem64Solve = maze64solve.groupby("solver_algorithm")["solver_used_memory"].mean()

# %%
#creating time and memory computation for creating maze for size 128
maze128 = df.loc[df['env_height'] ==  128]
maze128solve = maze128[["env_width","solver_algorithm","solver_epoch","solver_time","solver_used_memory","solver_steps"]]
maze128gen = maze128[["env_algorithm","env_generation_time","env_height","env_used_memory"]]
print(len(maze128solve))
maze128gen = maze128gen.drop_duplicates()
time128 = maze128gen.groupby("env_algorithm")["env_generation_time"].mean()
mem128 = maze128gen.groupby("env_algorithm")["env_used_memory"].mean()
#creating time and memory computation for creating maze for size 128
maze128solve = maze128solve.drop_duplicates()
steps128Solve = maze128solve.groupby("solver_algorithm")["solver_steps"].mean()
time128Solve = maze128solve.groupby("solver_algorithm")["solver_time"].mean()
mem128Solve = maze128solve.groupby("solver_algorithm")["solver_used_memory"].mean()

# %%
# drawing diagram of Memory usage for all the algorithms when we have both Kruskal and DFS for creating the maze
x = [8,16,32,64,128]
y = [mem8Solve["BodyRandomMazeSolver"],mem16Solve["BodyRandomMazeSolver"],mem32Solve["BodyRandomMazeSolver"],mem64Solve["BodyRandomMazeSolver"],mem128Solve["BodyRandomMazeSolver"]]
y2 = [mem8Solve["BestFirstMazeSolver"],mem16Solve["BestFirstMazeSolver"],mem32Solve["BestFirstMazeSolver"],mem64Solve["BestFirstMazeSolver"],mem128Solve["BestFirstMazeSolver"]]
y3 = [mem8Solve["AStarMazeSolver"],mem16Solve["AStarMazeSolver"],mem32Solve["AStarMazeSolver"],mem64Solve["AStarMazeSolver"],mem128Solve["AStarMazeSolver"]]
y4 = [mem8Solve["WallFollowerMazeSolver"],mem16Solve["WallFollowerMazeSolver"],mem32Solve["WallFollowerMazeSolver"],mem64Solve["WallFollowerMazeSolver"],mem128Solve["WallFollowerMazeSolver"]]
y5 = [mem8Solve["HeadRandomMazeSolver"],mem16Solve["HeadRandomMazeSolver"],mem32Solve["HeadRandomMazeSolver"],mem64Solve["HeadRandomMazeSolver"],mem128Solve["HeadRandomMazeSolver"]]
y6 = [mem8Solve["BreadthFirstMazeSolver"],mem16Solve["BreadthFirstMazeSolver"],mem32Solve["BreadthFirstMazeSolver"],mem64Solve["BreadthFirstMazeSolver"],mem128Solve["BreadthFirstMazeSolver"]]
mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
plt.plot(x, y,label="Representatives" )
plt.plot(x, y2,label="Representatives" )
plt.plot(x, y3,label="Representatives")
plt.plot(x, y4,label="Representatives")
plt.plot(x, y5,label="Representatives")
plt.plot(x, y6,label="Representatives")
plt.legend(["BodyRandomMazeSolver", "BestFirstMazeSolver","AStarMazeSolver","WallFollowerMazeSolver","HeadRandomMazeSolver","BreadthFirstMazeSolver"])
plt.xlabel('Size of the maze', fontsize=13)
plt.ylabel('Memory (bytes)', fontsize=13)
plt.title('Memory usage', fontsize=13)
plt.savefig('MemooryUsagePathfinding', dpi=300)
plt.show()

# %%
# drawing diagram of Time usage for the algorithms when we have both Kruskal and DFS for creating the maze
x = [8,16,32,64,128]
y = [time8Solve["BodyRandomMazeSolver"],time16Solve["BodyRandomMazeSolver"],time32Solve["BodyRandomMazeSolver"],time64Solve["BodyRandomMazeSolver"],time128Solve["BodyRandomMazeSolver"]]
y2 = [time8Solve["BestFirstMazeSolver"],time16Solve["BestFirstMazeSolver"],time32Solve["BestFirstMazeSolver"],time64Solve["BestFirstMazeSolver"],time128Solve["BestFirstMazeSolver"]]
y3 = [time8Solve["AStarMazeSolver"],time16Solve["AStarMazeSolver"],time32Solve["AStarMazeSolver"],time64Solve["AStarMazeSolver"],time128Solve["AStarMazeSolver"]]
y4 = [time8Solve["WallFollowerMazeSolver"],time16Solve["WallFollowerMazeSolver"],time32Solve["WallFollowerMazeSolver"],time64Solve["WallFollowerMazeSolver"],time128Solve["WallFollowerMazeSolver"]]
y5 = [time8Solve["HeadRandomMazeSolver"],time16Solve["HeadRandomMazeSolver"],time32Solve["HeadRandomMazeSolver"],time64Solve["HeadRandomMazeSolver"],time128Solve["HeadRandomMazeSolver"]]
y6 = [time8Solve["BreadthFirstMazeSolver"],time16Solve["BreadthFirstMazeSolver"],time32Solve["BreadthFirstMazeSolver"],time64Solve["BreadthFirstMazeSolver"],time128Solve["BreadthFirstMazeSolver"]]

mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
# plt.plot(x, y, c='b',label='')
# plt.plot(x, y)
# plt.plot(x, y2)
plt.plot(x, y3,color="green")
# plt.plot(x, y4)
plt.plot(x, y5,color="purple")
plt.plot(x, y6,color="brown")
plt.legend(["AStarMazeSolver","HeadRandomMazeSolver","BreadthFirstMazeSolver"])
plt.xlabel('Size of the maze', fontsize=13)
plt.ylabel('Time (nanosecod)', fontsize=13)
plt.title('Time Usage', fontsize=13)
plt.savefig('TimeUsagePathfindingIndetail', dpi=300)
plt.show()

# %%
# drawing diagram of Time usage for all the algorithms when we have both Kruskal and DFS for creating the maze
x = [8,16,32,64,128]
y = [time8Solve["BodyRandomMazeSolver"],time16Solve["BodyRandomMazeSolver"],time32Solve["BodyRandomMazeSolver"],time64Solve["BodyRandomMazeSolver"],time128Solve["BodyRandomMazeSolver"]]
y2 = [time8Solve["BestFirstMazeSolver"],time16Solve["BestFirstMazeSolver"],time32Solve["BestFirstMazeSolver"],time64Solve["BestFirstMazeSolver"],time128Solve["BestFirstMazeSolver"]]
y3 = [time8Solve["AStarMazeSolver"],time16Solve["AStarMazeSolver"],time32Solve["AStarMazeSolver"],time64Solve["AStarMazeSolver"],time128Solve["AStarMazeSolver"]]
y4 = [time8Solve["WallFollowerMazeSolver"],time16Solve["WallFollowerMazeSolver"],time32Solve["WallFollowerMazeSolver"],time64Solve["WallFollowerMazeSolver"],time128Solve["WallFollowerMazeSolver"]]
y5 = [time8Solve["HeadRandomMazeSolver"],time16Solve["HeadRandomMazeSolver"],time32Solve["HeadRandomMazeSolver"],time64Solve["HeadRandomMazeSolver"],time128Solve["HeadRandomMazeSolver"]]
y6 = [time8Solve["BreadthFirstMazeSolver"],time16Solve["BreadthFirstMazeSolver"],time32Solve["BreadthFirstMazeSolver"],time64Solve["BreadthFirstMazeSolver"],time128Solve["BreadthFirstMazeSolver"]]

mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))

plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)
plt.plot(x, y6)
plt.legend(["BodyRandomMazeSolver", "BestFirstMazeSolver","AStarMazeSolver","WallFollowerMazeSolver","HeadRandomMazeSolver","BreadthFirstMazeSolver"])
plt.xlabel('Size of the maze', fontsize=13)
plt.ylabel('Time (nanosecod)', fontsize=13)
plt.title('Time Usage', fontsize=13)
plt.savefig('TimeUsagePathfinding', dpi=300)
plt.show()

# %%
# drawing diagram of Number of steps (path finding) for all the algorithms when we have both Kruskal and DFS for creating the maze
x = [8,16,32,64,128]
y = [steps8Solve["BodyRandomMazeSolver"],steps16Solve["BodyRandomMazeSolver"],steps32Solve["BodyRandomMazeSolver"],steps64Solve["BodyRandomMazeSolver"],steps128Solve["BodyRandomMazeSolver"]]
y2 = [steps8Solve["BestFirstMazeSolver"],steps16Solve["BestFirstMazeSolver"],steps32Solve["BestFirstMazeSolver"],steps64Solve["BestFirstMazeSolver"],steps128Solve["BestFirstMazeSolver"]]
y3 = [steps8Solve["AStarMazeSolver"],steps16Solve["AStarMazeSolver"],steps32Solve["AStarMazeSolver"],steps64Solve["AStarMazeSolver"],steps128Solve["AStarMazeSolver"]]
y4 = [steps8Solve["WallFollowerMazeSolver"],steps16Solve["WallFollowerMazeSolver"],steps32Solve["WallFollowerMazeSolver"],steps64Solve["WallFollowerMazeSolver"],steps128Solve["WallFollowerMazeSolver"]]
y5 = [steps8Solve["HeadRandomMazeSolver"],steps16Solve["HeadRandomMazeSolver"],steps32Solve["HeadRandomMazeSolver"],steps64Solve["HeadRandomMazeSolver"],steps128Solve["HeadRandomMazeSolver"]]
y6 = [steps8Solve["BreadthFirstMazeSolver"],steps16Solve["BreadthFirstMazeSolver"],steps32Solve["BreadthFirstMazeSolver"],steps64Solve["BreadthFirstMazeSolver"],steps128Solve["BreadthFirstMazeSolver"]]

mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.plot(x, y5)
plt.plot(x, y6)
plt.legend(["BodyRandomMazeSolver", "BestFirstMazeSolver","AStarMazeSolver","WallFollowerMazeSolver","HeadRandomMazeSolver","BreadthFirstMazeSolver"])
plt.xlabel('Size of the maze', fontsize=13)
plt.ylabel('steps', fontsize=13)
plt.title('Solver steps', fontsize=13)
plt.savefig('SolverStepsPathfinding', dpi=300)
plt.show()

# %%
# drawing diagram of Number of steps (path finding) for all the algorithms except the when we have both Kruskal and DFS for creating the maze
x = [8,16,32,64,128]
y = [steps8Solve["BodyRandomMazeSolver"],steps16Solve["BodyRandomMazeSolver"],steps32Solve["BodyRandomMazeSolver"],steps64Solve["BodyRandomMazeSolver"],steps128Solve["BodyRandomMazeSolver"]]
y2 = [steps8Solve["BestFirstMazeSolver"],steps16Solve["BestFirstMazeSolver"],steps32Solve["BestFirstMazeSolver"],steps64Solve["BestFirstMazeSolver"],steps128Solve["BestFirstMazeSolver"]]
y3 = [steps8Solve["AStarMazeSolver"],steps16Solve["AStarMazeSolver"],steps32Solve["AStarMazeSolver"],steps64Solve["AStarMazeSolver"],steps128Solve["AStarMazeSolver"]]
y4 = [steps8Solve["WallFollowerMazeSolver"],steps16Solve["WallFollowerMazeSolver"],steps32Solve["WallFollowerMazeSolver"],steps64Solve["WallFollowerMazeSolver"],steps128Solve["WallFollowerMazeSolver"]]
y5 = [steps8Solve["HeadRandomMazeSolver"],steps16Solve["HeadRandomMazeSolver"],steps32Solve["HeadRandomMazeSolver"],steps64Solve["HeadRandomMazeSolver"],steps128Solve["HeadRandomMazeSolver"]]
y6 = [steps8Solve["BreadthFirstMazeSolver"],steps16Solve["BreadthFirstMazeSolver"],steps32Solve["BreadthFirstMazeSolver"],steps64Solve["BreadthFirstMazeSolver"],steps128Solve["BreadthFirstMazeSolver"]]

mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))

plt.plot(x, y)
plt.plot(x, y2)
plt.plot(x, y3)
#plt.plot(x, y4)
plt.plot(x, y5,color="purple")
plt.plot(x, y6,color="brown")
plt.legend(["BodyRandomMazeSolver", "BestFirstMazeSolver","AStarMazeSolver","HeadRandomMazeSolver","BreadthFirstMazeSolver"])
plt.xlabel('Size of the maze', fontsize=13)
plt.ylabel('steps', fontsize=13)
plt.title('Solver steps', fontsize=13)
plt.savefig('SolverStepsPathfindingIndetail', dpi=300)
plt.show()

# %%
# drawing diagram of Memory Usage for both Kruskal and DFS for creating the maze
x = ["8x8","16x16","36x36","64x64","128x128"]
y = [mem8["KruskalMazeEnv"],mem16["KruskalMazeEnv"],mem32["KruskalMazeEnv"],mem64["KruskalMazeEnv"],mem128["KruskalMazeEnv"]]
x2 = ["8x8","16x16","36x36","64x64","128x128"]
y2 = [mem8["DepthFirstMazeEnv"],mem16["DepthFirstMazeEnv"],mem32["DepthFirstMazeEnv"],mem64["DepthFirstMazeEnv"],mem128["DepthFirstMazeEnv"]]
mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))

plt.xlabel('Size of the Maze', fontsize=13)
plt.ylabel('Memory (bytes)', fontsize=16)
plt.title('Memory usage', fontsize=16)



plt.plot(x, y)
plt.plot(x2, y2)

plt.legend(["Kruskal", "DFS"])
plt.savefig('MemoryUsageCreatingMaze', dpi=300)
plt.show()

# %%
# drawing diagram of time Usage for DFS for creating the maze
x = ["8x8","16x16","32x32","64x64","128x128"]
y = [time8["KruskalMazeEnv"],time16["KruskalMazeEnv"],time32["KruskalMazeEnv"],time64["KruskalMazeEnv"],time128["KruskalMazeEnv"]]
x2 = ["8x8","16x16","32x32","64x64","128x128"]
y2 = [time8["DepthFirstMazeEnv"],time16["DepthFirstMazeEnv"],time32["DepthFirstMazeEnv"],time64["DepthFirstMazeEnv"],time128["DepthFirstMazeEnv"]]
mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
# plt.plot(x, y)
# plt.plot(x2, y2)
# plt.xlabel('Size of Maze')
# plt.ylabel('Time (nanosecond)')
# # plt.title('Kruskal')
plt.xlabel('Size of the Maze', fontsize=13)
plt.ylabel('Time (nanosecond)', fontsize=16)
plt.title('Time usage', fontsize=16)


# plt.plot(x, y)
plt.plot(x2, y2)
plt.legend(["DFS"])
# plt.legend(["Kruskal", "DFS"])
plt.savefig('TimeUsageCreatingDFS', dpi=300)
plt.show()

# %%
# drawing diagram of time Usage for Keuskal for creating the maze
x = ["8x8","16x16","32x32","64x64","128x128"]
y = [time8["KruskalMazeEnv"],time16["KruskalMazeEnv"],time32["KruskalMazeEnv"],time64["KruskalMazeEnv"],time128["KruskalMazeEnv"]]
x2 = ["8x8","16x16","32x32","64x64","128x128"]
y2 = [time8["DepthFirstMazeEnv"],time16["DepthFirstMazeEnv"],time32["DepthFirstMazeEnv"],time64["DepthFirstMazeEnv"],time128["DepthFirstMazeEnv"]]
mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))

plt.xlabel('Size of the Maze', fontsize=13)
plt.ylabel('Time (nanosecond)', fontsize=16)
plt.title('Time usage', fontsize=16)
# plt.legend(["Kruskal", "DFS"])

# Data for the second line

# y2 = [6, 5, 4,10]

plt.plot(x, y)
# plt.plot(x2, y2)
plt.legend(["Kruskal"])
# plt.legend(["Kruskal", "DFS"])
plt.savefig('TimeUsageCreatingDFS', dpi=300)
plt.show()

# %%
# drawing diagram of time Usage for kruskal and DFS for creating the maze
x = ["8x8","16x16","32x32","64x64","128x128"]
y = [time8["KruskalMazeEnv"],time16["KruskalMazeEnv"],time32["KruskalMazeEnv"],time64["KruskalMazeEnv"],time128["KruskalMazeEnv"]]
x2 = ["8x8","16x16","32x32","64x64","128x128"]
y2 = [time8["DepthFirstMazeEnv"],time16["DepthFirstMazeEnv"],time32["DepthFirstMazeEnv"],time64["DepthFirstMazeEnv"],time128["DepthFirstMazeEnv"]]
mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
# plt.plot(x, y)
# plt.plot(x2, y2)
# plt.xlabel('Size of Maze')
# plt.ylabel('Time (nanosecond)')
# # plt.title('Kruskal')
plt.xlabel('Size of the Maze', fontsize=13)
plt.ylabel('Time (nanosecond)', fontsize=16)
plt.title('Time usage', fontsize=16)
# plt.legend(["Kruskal", "DFS"])

# Data for the second line

# y2 = [6, 5, 4,10]

plt.plot(x, y)
plt.plot(x2, y2)
# plt.legend(["DFS"])
plt.legend(["Kruskal", "DFS"])
plt.savefig('TimeUsageCreatingMaze', dpi=300)
plt.show()

# %%
y6

# %%
#Q learning section
dfQ = pd.DataFrame(pd.read_csv("../input/qlearning/QLearning-combined.csv"))
dfQ.info()

# %%
#Q learning section
dfQ = pd.DataFrame(pd.read_csv("../input/qlearningfinal2/ReinforcementData.csv"))
dfQ.info()

# %%
#creating data for drawing diagram of Number of steps and duration for maze 8 
maze8 = dfQ.loc[dfQ['env_height'] ==  8]
maze8Duration = maze8.loc[maze8['successful'] ==  1]
array8Step=[]
array8Duration=[]
for i in range(0,50):
    count=0
    count2=0
    for j in range(0,10):
        
        count+=maze8["episode-"+str(10*i+j)+"-successful"].sum()
        count2+=maze8Duration["episode-"+str(10*i+j)+"-duration"].sum()
    array8Step.append(count)
    array8Duration.append(count2)

# %%
#creating data for drawing diagram of Number of steps for maze 16
maze16 = dfQ.loc[dfQ['env_height'] ==  16]
maze16Duration = maze16.loc[maze16['successful'] ==  1]
array16Step=[]
array16Duration=[]

for i in range(0,50):
    count=0
    count2=0
    for j in range(0,10):
        
        count+=maze16["episode-"+str(10*i+j)+"-successful"].sum()
        count2+=maze16Duration["episode-"+str(10*i+j)+"-duration"].sum()
    array16Step.append(count)
    array16Duration.append(count2)

# %%
#creating data for drawing diagram of Number of steps for maze 32
maze32 = dfQ.loc[dfQ['env_height'] ==  32]
maze32Duration = maze32.loc[maze32['successful'] ==  1]
array32Step=[]
array32Duration=[]
for i in range(0,50):
    count=0
    count2=0
    for j in range(0,10):
        
        count+=maze32["episode-"+str(10*i+j)+"-successful"].sum()
        count2+=maze32Duration["episode-"+str(10*i+j)+"-duration"].sum()
    array32Step.append(count)
    array32Duration.append(count2)

# %%
#creating data for drawing diagram of Number of steps for maze 64 
maze64 = dfQ.loc[dfQ['env_height'] ==  64]
maze64Duration = maze64.loc[maze64['successful'] ==  1]
array64Step=[]
array64Duration=[]
for i in range(0,50):
    count=0
    count2=0
    for j in range(0,10):
        
        count+=maze64["episode-"+str(10*i+j)+"-successful"].sum()
        count2+=maze64Duration["episode-"+str(10*i+j)+"-duration"].sum()
    array64Step.append(count)
    array64Duration.append(count2)

# %%
#creating data for drawing diagram of Number of steps and Duration for maze 128
maze128 = dfQ.loc[dfQ['env_height'] == 128]
maze128Duration = maze128.loc[maze128['successful'] ==  1]
array128Step=[]
array128Duration=[]
for i in range(0,50):
    count=0
    count2=0
    for j in range(0,10):
        
        count+=maze128["episode-"+str(10*i+j)+"-successful"].sum()
        count2+=maze128Duration["episode-"+str(10*i+j)+"-duration"].sum()
    array128Step.append(count)
    array128Duration.append(count2)

# %%
# drawing diagram of Number of sucess in each episodes
x=[]
for b in range(0,50):
    x.append(b)

mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
# plt.plot(x, y, c='b',label='')
plt.plot(x, array8Step)
plt.plot(x, array16Step)
plt.plot(x, array32Step)
plt.plot(x, array64Step)
plt.plot(x, array128Step)
plt.xlabel('Episodes', fontsize=13)
plt.legend(["Size 8", "Size 16","Size 32","Size 64","Size 128"])
plt.ylabel('Number of sucess', fontsize=13)
plt.title('Number of sucess in episodes', fontsize=13)
plt.savefig('NumberOfSuccessEachEpisodedQlearning', dpi=300)
plt.show()

# %%
# drawing diagram of Episode length over Time
x=[]
for b in range(0,50):
    x.append(b)
mpl.style.use('default')
fig, ax = plt.subplots(figsize=(10, 4))
# plt.plot(x, y, c='b',label='')
plt.plot(x, array8Duration)
plt.plot(x, array16Duration)
plt.plot(x, array32Duration)
plt.plot(x, array64Duration)
plt.plot(x, array128Duration)
plt.legend(["Size 8", "Size 16","Size 32","Size 64","Size 128"])
plt.xlabel('Episode', fontsize=13)
plt.ylabel('Episode Length', fontsize=13)
plt.title('Episode Length over Time', fontsize=13)
plt.savefig('EpisodeLengthOverTimeQlearning', dpi=300)
plt.show()
